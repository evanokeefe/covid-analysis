# %%
from covid import *
import pandas as pd

cases = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'


df = get_data(cases)
df = get_state(df, 'Wisconsin')
df = select_dates(df)
daily_cases(df, 5)
#[5:]#.plot()
# Out:
#            UID iso2 iso3  code3     FIPS     Admin2 Province_State  \
# 3241  84055001   US  USA    840  55001.0      Adams      Wisconsin
# 3242  84055003   US  USA    840  55003.0    Ashland      Wisconsin
# 3243  84055005   US  USA    840  55005.0     Barron      Wisconsin
# 3244  84055007   US  USA    840  55007.0   Bayfield      Wisconsin
# 3245  84055009   US  USA    840  55009.0      Brown      Wisconsin
# ...        ...  ...  ...    ...      ...        ...            ...
# 3310  84055133   US  USA    840  55133.0   Waukesha      Wisconsin
# 3311  84055135   US  USA    840  55135.0    Waupaca      Wisconsin
# 3312  84055137   US  USA    840  55137.0   Waushara      Wisconsin
# 3313  84055139   US  USA    840  55139.0  Winnebago      Wisconsin
# 3314  84055141   US  USA    840  55141.0       Wood      Wisconsin
#
#      Country_Region        Lat      Long_  ... 9/9/20  9/10/20  9/11/20  \
# 3241             US  43.969747 -89.767828  ...    3.2      2.4      1.6
# 3242             US  46.319569 -90.678371  ...    0.2      0.2      0.2
# 3243             US  45.423727 -91.848336  ...    2.2      1.8      1.2
# 3244             US  46.528688 -91.197167  ...    2.6      2.6      2.2
# 3245             US  44.452655 -88.004118  ...   75.6     77.8     77.8
# ...             ...        ...        ...  ...    ...      ...      ...
# 3310             US  43.018331 -88.304312  ...   26.4     30.6     38.4
# 3311             US  44.470681 -88.965345  ...    9.8      7.8      7.2
# 3312             US  44.113244 -89.243171  ...    4.6      6.0      6.8
# 3313             US  44.068869 -88.644771  ...   20.6     23.0     33.2
# 3314             US  44.455379 -90.041583  ...    6.4      5.0      6.0
#
#       9/12/20  9/13/20  9/14/20  9/15/20  9/16/20  9/17/20  9/18/20
# 3241      2.2      2.8      2.6      3.8      4.0      4.2      4.0
# 3242      0.2      1.0      0.8      0.8      0.8      0.8      1.4
# 3243      0.6      0.6      1.0      0.8      0.8      0.6      2.2
# 3244      2.0      1.6      0.8      0.4      0.2      0.2      2.0
# 3245     96.2    119.8     84.6     96.2    116.6    129.4    138.4
# ...       ...      ...      ...      ...      ...      ...      ...
# 3310     42.0     48.4     49.0     45.8     45.8     46.8     67.4
# 3311      6.6      6.8      6.4      6.4      6.6      7.0     10.4
# 3312      6.6      6.6      7.2      6.4      4.6      3.8      5.0
# 3313     42.2     53.2     54.2     64.4     61.4     65.2     92.6
# 3314      6.6      8.8      8.2      9.8     12.2     12.8     15.6
#
# [74 rows x 251 columns]

# %%
import warnings

df = get_data(cases)
df = get_state(df, ['Wisconsin'], True)

df = daily_cases(df)
#select_dates(df, '9/1/20')
# Out:
# <AxesSubplot:>
